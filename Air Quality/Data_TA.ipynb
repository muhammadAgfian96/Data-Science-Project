# %%
# for cleaning, exploraty data
import pandas as pd, numpy as np

# for data viz.
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# for predicting
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics

import datetime

# %%
def show_plot(col, tanggal,r_max, r_min, step=10):
    
    kondisi = df['date']<'2019-10-'+str(tanggal+1)
    konidisi_2 =df['date']>'2019-10-'+str(tanggal)
    
    grafik = sns.lineplot(x=df[kondisi & konidisi_2]['date'], 
                 y=df[kondisi & konidisi_2][col]
                )
    
    if (df[kondisi & konidisi_2][col].max() > r_max or df[kondisi & konidisi_2][col].min() < r_min):
        grafik
    else:
        grafik.set_yticks(np.arange(r_min, r_max, step))
    
#     sns.plt.ylim(0, 20)
#     plt.xlim('2019-10-08 00:00:00.0', None)

    plt.xticks(rotation=90)
    plt.title("{col} {tanggal}"
              .format(col=col, 
                      tanggal='2019-10-'+str(tanggal)), 
            fontdict={
              'fontweight':'bold',
            'fontsize': 15},
              pad=5
             )

# %%
df['date'][0].hour
# Out:
# 9

# %% [markdown]
# # ==== Data Senin 8-10-2019

# %%
df = pd.read_excel('data_14_10_19.xlsx', sheet_name='day8', parse_dates=['date'])

# %%
df.drop(columns=['Timestamp'], inplace=True)

# %%
idx_drop = df[df['date']<'2019-10-08 12:59:58'].index
df.drop(index=idx_drop,inplace=True)

# %%
df.head()
# Out:
#                        date      CO2        O2  PM   RH    T  TVOC  \
# 990 2019-10-08 12:59:59.514  300.000  20.63688  27  0.0  0.0     0
# 991 2019-10-08 13:00:06.758  353.125  20.63688  29  0.0  0.0     0
# 992 2019-10-08 13:00:13.955  390.625  20.63688  27  0.0  0.0     0
# 993 2019-10-08 13:00:21.154  400.000  20.63688  27  0.0  0.0     0
# 994 2019-10-08 13:00:28.386  418.750  20.63688  28  0.0  0.0    13
#
#      mVoltageCO2
# 990     496.6875
# 991     513.5625
# 992     525.7500
# 993     528.0000
# 994     534.3750

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18117 entries, 990 to 19106
# Data columns (total 8 columns):
# date           18115 non-null datetime64[ns]
# CO2            18117 non-null float64
# O2             18117 non-null float64
# PM             18117 non-null int64
# RH             18117 non-null float64
# T              18117 non-null float64
# TVOC           18117 non-null int64
# mVoltageCO2    18117 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#                 CO2            O2            PM       RH        T  \
# count  18117.000000  18117.000000  18117.000000  18117.0  18117.0
# mean     400.920751     20.517280     69.740686      0.0      0.0
# std       54.844359      0.049661     19.175031      0.0      0.0
# min     -625.000000     20.426300     27.000000      0.0      0.0
# 25%      393.750000     20.478950     53.000000      0.0      0.0
# 50%      393.750000     20.478950     69.000000      0.0      0.0
# 75%      403.125000     20.584240     84.000000      0.0      0.0
# max     4643.750000     20.689530    112.000000      0.0      0.0
#
#                TVOC   mVoltageCO2
# count  18117.000000  18117.000000
# mean      15.475796    528.854477
# std       17.448275     17.534832
# min        0.000000    199.312500
# 25%        5.000000    526.687500
# 50%       10.000000    526.687500
# 75%       18.000000    529.875000
# max      116.000000   1886.813000

# %%
col = ['CO2','O2','PM','RH','T','TVOC','mVoltageCO2']
dates = [8,9,10]

# %%
# df['date']

# %% [markdown]
# ## <font color='blue'># DATA CO2</font>

# %%
plt.figure(figsize=(8,15))

j=0
pos=1

sns.set_style("whitegrid")

for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[0], dates[j], r_max=550, r_min=200, step=50)
    pos+=1
    
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## <font color='blue'># DATA O2</font>

# %%
plt.figure(figsize=(8,15))

j=0
pos=1

sns.set_style("whitegrid")

for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[1], dates[j], r_max=25, r_min=15, step=1)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# ## <font color='blue'># DATA PM2.5</font>

# %%
plt.figure(figsize=(8,15))

j=0
pos=1

sns.set_style("whitegrid")

for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[2], dates[j], r_max=100, r_min=0, step=5)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # === Data Senin 14 10 2019

# %%
df = pd.read_excel('data_14_10_19.xlsx', sheet_name='day14', parse_dates=['date'])

# %%
df.drop(columns=['Timestamp'], inplace=True)

# %%
df.tail()
# Out:
#                          date      CO2        O2  PM  RH  T  TVOC  mVoltageCO2
# 49838 2019-10-14 06:16:33.579  393.750  20.47895  61   0  0    11     526.6875
# 49839 2019-10-14 06:16:40.718  393.750  20.47895  61   0  0    14     526.6875
# 49840 2019-10-14 06:16:48.156  396.875  20.42630  61   0  0    14     527.4375
# 49841 2019-10-14 06:16:55.168  396.875  20.47895  61   0  0     6     527.4375
# 49842 2019-10-14 06:17:02.310  400.000  20.42630  61   0  0     2     528.1875

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49843 entries, 0 to 49842
# Data columns (total 8 columns):
# date           49843 non-null datetime64[ns]
# CO2            49843 non-null float64
# O2             49843 non-null float64
# PM             49843 non-null int64
# RH             49843 non-null int64
# T              49843 non-null int64
# TVOC           49843 non-null int64
# mVoltageCO2    49843 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(4)
# memory usage: 3.0 MB

# %%
df.describe()
# Out:
#                 CO2            O2            PM       RH        T  \
# count  49843.000000  49843.000000  49843.000000  49843.0  49843.0
# mean     400.598379     20.481579     62.672893      0.0      0.0
# std       51.669895      0.596042     25.456835      0.0      0.0
# min    -1250.000000      0.263226      0.000000      0.0      0.0
# 25%      393.750000     20.478950     46.000000      0.0      0.0
# 50%      393.750000     20.478950     59.000000      0.0      0.0
# 75%      409.375000     20.531590     71.000000      0.0      0.0
# max     2118.750000     20.636880    175.000000      0.0      0.0
#
#                TVOC   mVoltageCO2
# count  49843.000000  49843.000000
# mean      17.310856    528.750602
# std       16.946771     16.536298
# min        0.000000     -0.187500
# 25%        7.000000    526.687500
# 50%       12.000000    526.687500
# 75%       21.000000    531.562500
# max      138.000000   1078.500000

# %%
col = ['CO2','O2','PM','RH','T','TVOC','mVoltageCO2']
dates = [10,11,12,13,14]

# %% [markdown]
# # <font color='green'>DATA CO2</font>

# %%
plt.figure(figsize=(10,20))

j=0
pos=1

sns.set_style("whitegrid")

for j in range(len(dates)):
    plt.subplot(len(dates), 1, pos)
    show_plot(col[0], dates[j], r_max=550, r_min=200, step=50)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # <font color='green'>DATA O2</font>

# %%
plt.figure(figsize=(10,20))

j=0
pos=1
sns.set_style("whitegrid")

for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[1], dates[j], r_max=25, r_min=15, step=1)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # <font color='green'>DATA PM2.5</font>

# %%
plt.figure(figsize=(10,20))

j=0
pos=1
sns.set_style("whitegrid")
for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[2], dates[j], r_max=100, r_min=0, step=10)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # DATA TVOC

# %%
plt.figure(figsize=(10,20))

j=0
pos=1
sns.set_style("whitegrid")
for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[5], dates[j], r_max=150, r_min=-10, step=25)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # <font color='green'> DATA mVoltageCO2</font>

# %%
plt.figure(figsize=(10,20))

j=0
pos=1
sns.set_style("whitegrid")
for j in range(len(dates)): 
    plt.subplot(len(dates), 1, pos)
    show_plot(col[6], dates[j], r_max=650, r_min=300, step=50)
    pos+=1
    
plt.tight_layout()

# %% [markdown]
# # Data Outdoor

# %%
df_out = pd.read_excel('outdoor.xlsx')

# %%
df_out.head()
# Out:
#   2019-09-13 15:36:15  28.10  51.00  0   746.88
# 0 2019-09-13 15:36:17   27.7   52.9  0   671.88
# 1 2019-09-13 15:36:20   27.7   52.9  0  1159.38
# 2 2019-09-13 15:36:22   27.6   52.9  0  3478.12
# 3 2019-09-13 15:36:25   27.6   53.1  0  1112.50
# 4 2019-09-13 15:36:28   27.6   53.0  0  1831.25
